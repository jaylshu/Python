# %% [markdown]
# # Urbanization Analysis of US Congressional Districts

# %% [markdown]
# ## The US Midterm elections in November 2022 returned some surprising results counter to many forecasts. What many pundits and media outlets had forecasted as a red wave, it was actually more like a red ripple.

# %% [markdown]
# ## In this notebook, let's explore if urbanization data of the redrawn congressional districts could have predicted the result. The urbanization index is calculated as the natural logarithm of the average number of people living within a five-mile radius of every census tract in a given district, based on a weighted average of the population of each census tract.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Import data from fivethirtyeight's github
df_urban = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/243811d9554da444b4e9d331c749fa7209e1e068/district-urbanization-index-2022/urbanization-index-2022.csv')

# %%
#435 congressional districts, redrawn after the 2020 Census
df_urban
# Out:
#       stcd state  cd    pvi_22  urbanindex     rural   exurban  suburban  \
# 0    NY-12    NY  12  67.84485    14.90340   0.00000   0.00000   0.00000
# 1    NY-07    NY   7  62.84295    14.85414   0.00000   0.00000   0.00000
# 2    NY-09    NY   9  51.11625    14.69678   0.00000   0.00000   0.00000
# 3    NY-13    NY  13  77.13841    14.69063   0.00000   0.00000   0.00000
# 4    NY-15    NY  15  70.80064    14.65565   0.00000   0.00000   0.00000
# ..     ...   ...  ..       ...         ...       ...       ...       ...
# 430  WY-01    WY   1 -49.87336     8.52656  69.09393  30.90607   0.00000
# 431  WI-07    WI   7 -23.90953     8.42007  82.10666  17.89334   0.00000
# 432  MI-01    MI   1 -23.76232     8.35040  93.53532   6.46468   0.00000
# 433  NE-03    NE   3 -56.57166     8.26581  78.46326  21.08780   0.44895
# 434  MN-07    MN   7 -36.62912     8.14396  92.16631   2.86388   4.96981
#
#      urban      grouping
# 0    100.0   Dense Urban
# 1    100.0   Dense Urban
# 2    100.0   Dense Urban
# 3    100.0   Dense Urban
# 4    100.0   Dense Urban
# ..     ...           ...
# 430    0.0  Mostly Rural
# 431    0.0  Mostly Rural
# 432    0.0  Mostly Rural
# 433    0.0  Mostly Rural
# 434    0.0  Mostly Rural
#
# [435 rows x 10 columns]

# %% [markdown]
# ### It's often said that the cities lean Democratic and rural areas lean Republican, with the suburbs being where the real election battleground takes place. Let's see if this hypothesis holds up to the data.
#
# ### Let's first do some descriptive analysis of the data. The data dictionary can be found here: https://github.com/fivethirtyeight/data/tree/master/district-urbanization-index-2022

# %%
df_urban.grouping.value_counts(normalize = 'True').plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='grouping'>

# %% [markdown]
# ### Looks like about half of all congressional districts can be considered suburban, more than either urban or rural districts.

# %% [markdown]
# ### fivethirtyeight has also included their partisan lean index as the pvi_22 column, weighted by past elections. Positive values indicate a Democratic lean, negative values indicate a Republican lean.

# %%
sns.histplot(data = df_urban, x = 'pvi_22', bins = 30, kde=True)
# Out:
# <AxesSubplot:xlabel='pvi_22', ylabel='Count'>

# %% [markdown]
# ### There seem to be a wider range of Democratic-leaning districts, while the Republican-leaning districts are more concentrated in the +20-40 range.

# %%
#Average partisan lean and urbanization index by state
df_state_summary = df_urban[['state', 'pvi_22', 'urbanindex']].groupby('state').mean().sort_values(by=['pvi_22'], ascending = False)
df_state_summary
# Out:
#           pvi_22  urbanindex
# state
# MA     33.936409   11.857520
# HI     31.812175   11.190180
# VT     27.772880    9.053380
# CA     26.202552   12.216909
# MD     26.182079   11.746070
# NY     24.177149   12.631584
# RI     24.070475   11.761065
# IL     14.940652   11.675868
# DE     13.916320   11.047340
# WA     13.113394   11.256539
# NJ     12.720977   12.276043
# CT     12.256304   11.404242
# OR     11.534648   10.868580
# NM      6.729927   10.143870
# CO      6.306947   11.308069
# VA      3.368448   11.050165
# ME      2.851150    9.223950
# MN      2.039671   10.634021
# NH      0.584605   10.131110
# MI     -0.459346   10.889388
# NV     -0.555497   11.888320
# WI     -2.781598   10.304005
# PA     -3.093205   11.214869
# AZ     -3.763358   11.450620
# NC     -4.915409   10.530419
# FL     -6.101121   11.554826
# GA     -6.901394   10.804029
# TX     -7.732501   11.313365
# IA     -9.753497    9.783373
# OH    -11.707565   10.952239
# AK    -14.617950    8.734400
# SC    -19.326906   10.341626
# IN    -19.420056   10.527599
# LA    -19.665923   10.369697
# MT    -19.850970    8.782625
# MS    -20.424145    9.267360
# MO    -20.707719   10.407600
# KS    -21.544180   10.219717
# NE    -25.376793   10.376950
# UT    -26.054232   11.194128
# KY    -27.868958   10.047503
# TN    -28.032492   10.362301
# AL    -29.748620    9.897976
# AR    -31.921310    9.567127
# SD    -32.010050    8.969800
# WV    -34.489815    9.333795
# ID    -36.068735   10.004290
# ND    -37.076630    9.262110
# OK    -37.885636   10.178130
# WY    -49.873360    8.526560

# %%
#Looks good, let's pretty it up for easier reading
df_state_summary.style.background_gradient(axis = 0, cmap = 'RdBu')
# Out:
# <style type="text/css">
# #T_78999_row0_col0, #T_78999_row5_col1 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_78999_row0_col1 {
#   background-color: #3f8ec0;
#   color: #f1f1f1;
# }
# #T_78999_row1_col0 {
#   background-color: #0c3d73;
#   color: #f1f1f1;
# }
# #T_78999_row1_col1, #T_78999_row39_col1 {
#   background-color: #b1d5e7;
#   color: #000000;
# }
# #T_78999_row2_col0 {
#   background-color: #195696;
#   color: #f1f1f1;
# }
# #T_78999_row2_col1 {
#   background-color: #bb2a34;
#   color: #f1f1f1;
# }
# #T_78999_row3_col0, #T_78999_row4_col0 {
#   background-color: #1e61a5;
#   color: #f1f1f1;
# }
# #T_78999_row3_col1 {
#   background-color: #2065ab;
#   color: #f1f1f1;
# }
# #T_78999_row4_col1 {
#   background-color: #4f9bc7;
#   color: #f1f1f1;
# }
# #T_78999_row5_col0 {
#   background-color: #266caf;
#   color: #f1f1f1;
# }
# #T_78999_row6_col0 {
#   background-color: #276eb0;
#   color: #f1f1f1;
# }
# #T_78999_row6_col1 {
#   background-color: #4c99c6;
#   color: #f1f1f1;
# }
# #T_78999_row7_col0 {
#   background-color: #59a1ca;
#   color: #f1f1f1;
# }
# #T_78999_row7_col1 {
#   background-color: #5ca3cb;
#   color: #f1f1f1;
# }
# #T_78999_row8_col0 {
#   background-color: #62a7ce;
#   color: #f1f1f1;
# }
# #T_78999_row8_col1, #T_78999_row15_col1 {
#   background-color: #c7e0ed;
#   color: #000000;
# }
# #T_78999_row9_col0 {
#   background-color: #68abd0;
#   color: #f1f1f1;
# }
# #T_78999_row9_col1 {
#   background-color: #a7d0e4;
#   color: #000000;
# }
# #T_78999_row10_col0 {
#   background-color: #6bacd1;
#   color: #f1f1f1;
# }
# #T_78999_row10_col1 {
#   background-color: #1d5fa2;
#   color: #f1f1f1;
# }
# #T_78999_row11_col0 {
#   background-color: #71b0d3;
#   color: #f1f1f1;
# }
# #T_78999_row11_col1 {
#   background-color: #90c4dd;
#   color: #000000;
# }
# #T_78999_row12_col0 {
#   background-color: #78b4d5;
#   color: #000000;
# }
# #T_78999_row12_col1 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_78999_row13_col0 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_78999_row13_col1, #T_78999_row18_col1 {
#   background-color: #fcd7c2;
#   color: #000000;
# }
# #T_78999_row14_col0 {
#   background-color: #a5cee3;
#   color: #000000;
# }
# #T_78999_row14_col1, #T_78999_row27_col1 {
#   background-color: #a0cce2;
#   color: #000000;
# }
# #T_78999_row15_col0 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_78999_row16_col0 {
#   background-color: #bddbea;
#   color: #000000;
# }
# #T_78999_row16_col1 {
#   background-color: #cb4942;
#   color: #f1f1f1;
# }
# #T_78999_row17_col0 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_78999_row17_col1, #T_78999_row26_col0 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_78999_row18_col0 {
#   background-color: #cfe4ef;
#   color: #000000;
# }
# #T_78999_row19_col0, #T_78999_row20_col0 {
#   background-color: #d5e7f1;
#   color: #000000;
# }
# #T_78999_row19_col1 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_78999_row20_col1 {
#   background-color: #3c8abe;
#   color: #f1f1f1;
# }
# #T_78999_row21_col0 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_78999_row21_col1 {
#   background-color: #fbe4d6;
#   color: #000000;
# }
# #T_78999_row22_col0, #T_78999_row26_col1 {
#   background-color: #e1edf3;
#   color: #000000;
# }
# #T_78999_row22_col1 {
#   background-color: #aed3e6;
#   color: #000000;
# }
# #T_78999_row23_col0 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_78999_row23_col1 {
#   background-color: #87beda;
#   color: #000000;
# }
# #T_78999_row24_col0 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_78999_row24_col1, #T_78999_row32_col1 {
#   background-color: #f8f3f0;
#   color: #000000;
# }
# #T_78999_row25_col0 {
#   background-color: #eff3f5;
#   color: #000000;
# }
# #T_78999_row25_col1 {
#   background-color: #75b2d4;
#   color: #f1f1f1;
# }
# #T_78999_row27_col0 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_78999_row28_col0 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_78999_row28_col1 {
#   background-color: #f5a886;
#   color: #000000;
# }
# #T_78999_row29_col0 {
#   background-color: #faeae1;
#   color: #000000;
# }
# #T_78999_row29_col1 {
#   background-color: #d4e6f1;
#   color: #000000;
# }
# #T_78999_row30_col0 {
#   background-color: #fce0d0;
#   color: #000000;
# }
# #T_78999_row30_col1 {
#   background-color: #8a0b25;
#   color: #f1f1f1;
# }
# #T_78999_row31_col0, #T_78999_row32_col0 {
#   background-color: #fac8af;
#   color: #000000;
# }
# #T_78999_row31_col1 {
#   background-color: #fae7dc;
#   color: #000000;
# }
# #T_78999_row33_col0, #T_78999_row46_col1 {
#   background-color: #f9c6ac;
#   color: #000000;
# }
# #T_78999_row33_col1, #T_78999_row41_col1 {
#   background-color: #fae8de;
#   color: #000000;
# }
# #T_78999_row34_col0 {
#   background-color: #f9c4a9;
#   color: #000000;
# }
# #T_78999_row34_col1 {
#   background-color: #930e26;
#   color: #f1f1f1;
# }
# #T_78999_row35_col0, #T_78999_row36_col0 {
#   background-color: #f8bfa4;
#   color: #000000;
# }
# #T_78999_row35_col1, #T_78999_row45_col0 {
#   background-color: #cf5246;
#   color: #f1f1f1;
# }
# #T_78999_row36_col1 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_78999_row37_col0 {
#   background-color: #f7b99c;
#   color: #000000;
# }
# #T_78999_row37_col1 {
#   background-color: #fcdecd;
#   color: #000000;
# }
# #T_78999_row38_col0 {
#   background-color: #f19e7d;
#   color: #000000;
# }
# #T_78999_row38_col1 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_78999_row39_col0 {
#   background-color: #ef9979;
#   color: #000000;
# }
# #T_78999_row40_col0 {
#   background-color: #e98b6e;
#   color: #f1f1f1;
# }
# #T_78999_row40_col1 {
#   background-color: #facab1;
#   color: #000000;
# }
# #T_78999_row41_col0 {
#   background-color: #e8896c;
#   color: #f1f1f1;
# }
# #T_78999_row42_col0 {
#   background-color: #e27b62;
#   color: #f1f1f1;
# }
# #T_78999_row42_col1 {
#   background-color: #f7b799;
#   color: #000000;
# }
# #T_78999_row43_col0, #T_78999_row44_col0 {
#   background-color: #da6853;
#   color: #f1f1f1;
# }
# #T_78999_row43_col1 {
#   background-color: #e58368;
#   color: #f1f1f1;
# }
# #T_78999_row44_col1 {
#   background-color: #b41c2d;
#   color: #f1f1f1;
# }
# #T_78999_row45_col1 {
#   background-color: #d55d4c;
#   color: #f1f1f1;
# }
# #T_78999_row46_col0 {
#   background-color: #c94741;
#   color: #f1f1f1;
# }
# #T_78999_row47_col0 {
#   background-color: #c53e3d;
#   color: #f1f1f1;
# }
# #T_78999_row47_col1 {
#   background-color: #ce4f45;
#   color: #f1f1f1;
# }
# #T_78999_row48_col0 {
#   background-color: #c13639;
#   color: #f1f1f1;
# }
# #T_78999_row48_col1 {
#   background-color: #fddbc7;
#   color: #000000;
# }
# #T_78999_row49_col0, #T_78999_row49_col1 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_78999_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >pvi_22</th>
#       <th class="col_heading level0 col1" >urbanindex</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78999_level0_row0" class="row_heading level0 row0" >MA</th>
#       <td id="T_78999_row0_col0" class="data row0 col0" >33.936409</td>
#       <td id="T_78999_row0_col1" class="data row0 col1" >11.857520</td>
#     </tr>
#     <tr>
#       <th id="T_78999_level0_row1" class="row_heading level0 row1" >HI</th>
#       <td id="T_78999_row1_col0" class="data row1 col0" >31.812175</td>
#       <td id="T_78999_row1_col1" class="data row1 col1" >11.190180</td>
#     </tr>
#     <tr>
#       <th id="T_78999_level0_row2" class="row_heading level0 row2" >VT</th>
#       <td id="T_78999_row2_col0" class="data row2 col0" >27.772880</td>
#       <td id="T_78999_row2_col1" class="data row2 col1" >9.053380</td>
#     </tr>
#     <tr>
#       <th id="T_78999_level0_row3" class="row_heading level0 row3" >CA</th>
#       <td id="T_78999_row3_col0" class="data row3 col0" >26.202552</td>
#       <td id="T_78999_row3_col1" class="data row3 col1" >12.216909</td>
#     </tr>
#     <tr>
#       <th id="T_78999_level0_row4" class="row_heading level0 row4" >MD</th>
#       <td id="T_78999_row4_col0" class="data row4 col0" >26.182079</td>
#       <td id="T_78999_row4_col1" class="data row4 col1" >11.746070</td>
#     </tr>
#     <tr>
#       <th id="T_78999_level0_row5" class="row_heading level0 row5" >NY</th>
#       <td id="T_78999_row5_col0" class="data row5 col0" >24.177149</td>

# %% [markdown]
# ### No major surprises, with the large coastal states leaning Democratic and the central and southern states leaning Republican. It's a bit difficult to derive an urbanization index correlation at the macro state level though, with multiple outliers like Vermont, Maine, Texas and Florida defying the trend.

# %%
#quick tangent to look more closely at the previously-identified outlier states
outlier_filter = df_urban.state.isin(['VT', 'ME', 'TX', 'FL'])
df_urban[outlier_filter].sort_values(by = ['state', 'pvi_22']).style.background_gradient(axis = 0, cmap = 'RdBu', subset = 'pvi_22')
# Out:
# <style type="text/css">
# #T_f330f_row0_col3 {
#   background-color: #c43b3c;
#   color: #f1f1f1;
# }
# #T_f330f_row1_col3 {
#   background-color: #d25849;
#   color: #f1f1f1;
# }
# #T_f330f_row2_col3 {
#   background-color: #df765e;
#   color: #f1f1f1;
# }
# #T_f330f_row3_col3, #T_f330f_row40_col3 {
#   background-color: #e48066;
#   color: #f1f1f1;
# }
# #T_f330f_row4_col3, #T_f330f_row45_col3 {
#   background-color: #e98b6e;
#   color: #f1f1f1;
# }
# #T_f330f_row5_col3, #T_f330f_row51_col3 {
#   background-color: #f19e7d;
#   color: #000000;
# }
# #T_f330f_row6_col3, #T_f330f_row52_col3 {
#   background-color: #f2a17f;
#   color: #000000;
# }
# #T_f330f_row7_col3 {
#   background-color: #f3a481;
#   color: #000000;
# }
# #T_f330f_row8_col3 {
#   background-color: #f7b596;
#   color: #000000;
# }
# #T_f330f_row9_col3 {
#   background-color: #f8bb9e;
#   color: #000000;
# }
# #T_f330f_row10_col3 {
#   background-color: #f9c4a9;
#   color: #000000;
# }
# #T_f330f_row11_col3 {
#   background-color: #facab1;
#   color: #000000;
# }
# #T_f330f_row12_col3 {
#   background-color: #fbd0b9;
#   color: #000000;
# }
# #T_f330f_row13_col3, #T_f330f_row14_col3 {
#   background-color: #fcd3bc;
#   color: #000000;
# }
# #T_f330f_row15_col3 {
#   background-color: #fcd7c2;
#   color: #000000;
# }
# #T_f330f_row16_col3 {
#   background-color: #fdd9c4;
#   color: #000000;
# }
# #T_f330f_row17_col3 {
#   background-color: #fae8de;
#   color: #000000;
# }
# #T_f330f_row18_col3 {
#   background-color: #f9f0eb;
#   color: #000000;
# }
# #T_f330f_row19_col3 {
#   background-color: #eff3f5;
#   color: #000000;
# }
# #T_f330f_row20_col3 {
#   background-color: #d2e6f0;
#   color: #000000;
# }
# #T_f330f_row21_col3 {
#   background-color: #b6d7e8;
#   color: #000000;
# }
# #T_f330f_row22_col3 {
#   background-color: #b3d6e8;
#   color: #000000;
# }
# #T_f330f_row23_col3, #T_f330f_row29_col3 {
#   background-color: #a7d0e4;
#   color: #000000;
# }
# #T_f330f_row24_col3 {
#   background-color: #9bc9e0;
#   color: #000000;
# }
# #T_f330f_row25_col3 {
#   background-color: #4997c5;
#   color: #f1f1f1;
# }
# #T_f330f_row26_col3, #T_f330f_row66_col3 {
#   background-color: #09386d;
#   color: #f1f1f1;
# }
# #T_f330f_row27_col3 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_f330f_row28_col3 {
#   background-color: #fcdfcf;
#   color: #000000;
# }
# #T_f330f_row30_col3 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_f330f_row31_col3 {
#   background-color: #7f0823;
#   color: #f1f1f1;
# }
# #T_f330f_row32_col3 {
#   background-color: #a21328;
#   color: #f1f1f1;
# }
# #T_f330f_row33_col3 {
#   background-color: #b82531;
#   color: #f1f1f1;
# }
# #T_f330f_row34_col3 {
#   background-color: #cc4c44;
#   color: #f1f1f1;
# }
# #T_f330f_row35_col3 {
#   background-color: #ce4f45;
#   color: #f1f1f1;
# }
# #T_f330f_row36_col3 {
#   background-color: #db6b55;
#   color: #f1f1f1;
# }
# #T_f330f_row37_col3 {
#   background-color: #dc6e57;
#   color: #f1f1f1;
# }
# #T_f330f_row38_col3 {
#   background-color: #dd7059;
#   color: #f1f1f1;
# }
# #T_f330f_row39_col3 {
#   background-color: #e37e64;
#   color: #f1f1f1;
# }
# #T_f330f_row41_col3, #T_f330f_row42_col3 {
#   background-color: #e58368;
#   color: #f1f1f1;
# }
# #T_f330f_row43_col3 {
#   background-color: #e6866a;
#   color: #f1f1f1;
# }
# #T_f330f_row44_col3 {
#   background-color: #e8896c;
#   color: #f1f1f1;
# }
# #T_f330f_row46_col3, #T_f330f_row47_col3 {
#   background-color: #ec9374;
#   color: #f1f1f1;
# }
# #T_f330f_row48_col3 {
#   background-color: #ee9677;
#   color: #000000;
# }
# #T_f330f_row49_col3, #T_f330f_row50_col3 {
#   background-color: #ef9979;
#   color: #000000;
# }
# #T_f330f_row53_col3 {
#   background-color: #fcd5bf;
#   color: #000000;
# }
# #T_f330f_row54_col3 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_f330f_row55_col3 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_f330f_row56_col3 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_f330f_row57_col3, #T_f330f_row58_col3 {
#   background-color: #6eaed2;
#   color: #f1f1f1;
# }
# #T_f330f_row59_col3 {
#   background-color: #5ca3cb;
#   color: #f1f1f1;
# }
# #T_f330f_row60_col3 {
#   background-color: #3a87bd;
#   color: #f1f1f1;
# }
# #T_f330f_row61_col3 {
#   background-color: #327cb7;
#   color: #f1f1f1;
# }
# #T_f330f_row62_col3 {
#   background-color: #2a71b2;
#   color: #f1f1f1;
# }
# #T_f330f_row63_col3 {
#   background-color: #1b5a9c;
#   color: #f1f1f1;
# }
# #T_f330f_row64_col3, #T_f330f_row65_col3 {
#   background-color: #185493;
#   color: #f1f1f1;
# }
# #T_f330f_row67_col3 {
#   background-color: #063264;
#   color: #f1f1f1;
# }
# #T_f330f_row68_col3 {
#   background-color: #529dc8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f330f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >stcd</th>
#       <th class="col_heading level0 col1" >state</th>
#       <th class="col_heading level0 col2" >cd</th>
#       <th class="col_heading level0 col3" >pvi_22</th>
#       <th class="col_heading level0 col4" >urbanindex</th>
#       <th class="col_heading level0 col5" >rural</th>
#       <th class="col_heading level0 col6" >exurban</th>
#       <th class="col_heading level0 col7" >suburban</th>
#       <th class="col_heading level0 col8" >urban</th>
#       <th class="col_heading level0 col9" >grouping</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f330f_level0_row0" class="row_heading level0 row0" >296</th>
#       <td id="T_f330f_row0_col0" class="data row0 col0" >FL-01</td>
#       <td id="T_f330f_row0_col1" class="data row0 col1" >FL</td>
#       <td id="T_f330f_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_f330f_row0_col3" class="data row0 col3" >-38.020110</td>
#       <td id="T_f330f_row0_col4" class="data row0 col4" >10.489310</td>
#       <td id="T_f330f_row0_col5" class="data row0 col5" >25.034830</td>
#       <td id="T_f330f_row0_col6" class="data row0 col6" >57.031540</td>
#       <td id="T_f330f_row0_col7" class="data row0 col7" >17.933630</td>
#       <td id="T_f330f_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_f330f_row0_col9" class="data row0 col9" >Rural-Exurban</td>
#     </tr>
#     <tr>
#       <th id="T_f330f_level0_row1" class="row_heading level0 row1" >249</th>
#       <td id="T_f330f_row1_col0" class="data row1 col0" >FL-12</td>
#       <td id="T_f330f_row1_col1" class="data row1 col1" >FL</td>
#       <td id="T_f330f_row1_col2" class="data row1 col2" >12</td>
#       <td id="T_f330f_row1_col3" class="data row1 col3" >-34.038240</td>
#       <td id="T_f330f_row1_col4" class="data row1 col4" >10.872480</td>
#       <td id="T_f330f_row1_col5" class="data row1 col5" >22.049380</td>
#       <td id="T_f330f_row1_col6" class="data row1 col6" >46.206890</td>
#       <td id="T_f330f_row1_col7" class="data row1 col7" >31.743730</td>
#       <td id="T_f330f_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_f330f_row1_col9" class="data row1 col9" >Suburban-Exurban</td>
#     </tr>
#     <tr>
#       <th id="T_f330f_level0_row2" class="row_heading level0 row2" >309</th>
#       <td id="T_f330f_row2_col0" class="data row2 col0" >FL-18</td>
#       <td id="T_f330f_row2_col1" class="data row2 col1" >FL</td>
#       <td id="T_f330f_row2_col2" class="data row2 col2" >18</td>
#       <td id="T_f330f_row2_col3" class="data row2 col3" >-29.300310</td>
#       <td id="T_f330f_row2_col4" class="data row2 col4" >10.275480</td>
#       <td id="T_f330f_row2_col5" class="data row2 col5" >36.401560</td>
#       <td id="T_f330f_row2_col6" class="data row2 col6" >50.579490</td>
#       <td id="T_f330f_row2_col7" class="data row2 col7" >13.018940</td>
#       <td id="T_f330f_row2_col8" class="data row2 col8" >0.000000</td>
#       <td id="T_f330f_row2_col9" class="data row2 col9" >Rural-Exurban</td>
#     </tr>
#     <tr>
#       <th id="T_f330f_level0_row3" class="row_heading level0 row3" >304</th>
#       <td id="T_f330f_row3_col0" class="data row3 col0" >FL-06</td>
#       <td id="T_f330f_row3_col1" class="data row3 col1" >FL</td>
#       <td id="T_f330f_row3_col2" class="data row3 col2" >6</td>
#       <td id="T_f330f_row3_col3" class="data row3 col3" >-27.794080</td>
#       <td id="T_f330f_row3_col4" class="data row3 col4" >10.348740</td>
#       <td id="T_f330f_row3_col5" class="data row3 col5" >30.349910</td>
#       <td id="T_f330f_row3_col6" class="data row3 col6" >58.377440</td>
#       <td id="T_f330f_row3_col7"

# %% [markdown]
# ### But within each of these outlier states and relative to other districts in each state, there does seem to be a correlation. E.g. in Florida and Texas, most districts with urbanization index > 12 seem to lean Democratic. Maine and Vermont only have 1-2 districts for the entire state so their Democratic lean may be driven by other factors, e.g. being situated in the Northeast surrounded by very blue states.

# %% [markdown]
# ### Let's now simply use the provided groupings based on urbanization index and analyze their partisan lean.

# %%
df_urban_summary = df_urban[['grouping', 'rural', 'exurban', 'suburban', 'urban', 'pvi_22']].groupby('grouping').mean().sort_values(by=['pvi_22'], ascending = False)
df_urban_summary.style.background_gradient(axis = None, cmap = 'RdBu', subset = 'pvi_22')
# Out:
# <style type="text/css">
# #T_c1107_row0_col4 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_c1107_row1_col4 {
#   background-color: #3e8cbf;
#   color: #f1f1f1;
# }
# #T_c1107_row2_col4 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_c1107_row3_col4 {
#   background-color: #f2a17f;
#   color: #000000;
# }
# #T_c1107_row4_col4 {
#   background-color: #960f27;
#   color: #f1f1f1;
# }
# #T_c1107_row5_col4 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c1107_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >rural</th>
#       <th class="col_heading level0 col1" >exurban</th>
#       <th class="col_heading level0 col2" >suburban</th>
#       <th class="col_heading level0 col3" >urban</th>
#       <th class="col_heading level0 col4" >pvi_22</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >grouping</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1107_level0_row0" class="row_heading level0 row0" >Dense Urban</th>
#       <td id="T_c1107_row0_col0" class="data row0 col0" >0.012039</td>
#       <td id="T_c1107_row0_col1" class="data row0 col1" >0.560487</td>
#       <td id="T_c1107_row0_col2" class="data row0 col2" >2.884455</td>
#       <td id="T_c1107_row0_col3" class="data row0 col3" >96.543021</td>
#       <td id="T_c1107_row0_col4" class="data row0 col4" >48.509671</td>
#     </tr>
#     <tr>
#       <th id="T_c1107_level0_row1" class="row_heading level0 row1" >Urban-Suburban</th>
#       <td id="T_c1107_row1_col0" class="data row1 col0" >0.565592</td>
#       <td id="T_c1107_row1_col1" class="data row1 col1" >1.508111</td>
#       <td id="T_c1107_row1_col2" class="data row1 col2" >19.148609</td>
#       <td id="T_c1107_row1_col3" class="data row1 col3" >78.777690</td>
#       <td id="T_c1107_row1_col4" class="data row1 col4" >33.917650</td>
#     </tr>
#     <tr>
#       <th id="T_c1107_level0_row2" class="row_heading level0 row2" >Dense Suburban</th>
#       <td id="T_c1107_row2_col0" class="data row2 col0" >3.453449</td>
#       <td id="T_c1107_row2_col1" class="data row2 col1" >16.066894</td>
#       <td id="T_c1107_row2_col2" class="data row2 col2" >50.076438</td>
#       <td id="T_c1107_row2_col3" class="data row2 col3" >30.403219</td>
#       <td id="T_c1107_row2_col4" class="data row2 col4" >14.233489</td>
#     </tr>
#     <tr>
#       <th id="T_c1107_level0_row3" class="row_heading level0 row3" >Suburban-Exurban</th>
#       <td id="T_c1107_row3_col0" class="data row3 col0" >21.588134</td>
#       <td id="T_c1107_row3_col1" class="data row3 col1" >34.574491</td>
#       <td id="T_c1107_row3_col2" class="data row3 col2" >37.484648</td>
#       <td id="T_c1107_row3_col3" class="data row3 col3" >6.352726</td>
#       <td id="T_c1107_row3_col4" class="data row3 col4" >-6.663297</td>
#     </tr>
#     <tr>
#       <th id="T_c1107_level0_row4" class="row_heading level0 row4" >Rural-Exurban</th>
#       <td id="T_c1107_row4_col0" class="data row4 col0" >46.857669</td>
#       <td id="T_c1107_row4_col1" class="data row4 col1" >35.329797</td>
#       <td id="T_c1107_row4_col2" class="data row4 col2" >17.640693</td>
#       <td id="T_c1107_row4_col3" class="data row4 col3" >0.171841</td>
#       <td id="T_c1107_row4_col4" class="data row4 col4" >-24.761391</td>
#     </tr>
#     <tr>
#       <th id="T_c1107_level0_row5" class="row_heading level0 row5" >Mostly Rural</th>
#       <td id="T_c1107_row5_col0" class="data row5 col0" >71.691897</td>
#       <td id="T_c1107_row5_col1" class="data row5 col1" >24.922537</td>
#       <td id="T_c1107_row5_col2" class="data row5 col2" >3.385566</td>
#       <td id="T_c1107_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_c1107_row5_col4" class="data row5 col4" >-29.881087</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### This seems to confirm the original hypothesis, that cities lean Democratic and rural areas lean Republican. And it seems to be the case that Dense Suburban and Suburban-Exurban Congressional seats are the most competitive, with partisan leans within +/- 15. The average dense suburban seat is D+14 and the average suburban-exurban seat is R+7.

# %%
#visualize relationship between urbanization index and partisan lean
sns.pairplot(df_urban, x_vars = 'urbanindex', y_vars = 'pvi_22', kind = 'reg')

# %% [markdown]
# ### Then is it as simple as saying the expected election outcome of a district is dependent entirely on the density of the population? Let's try something we did not do in class, which is a predictive model answering this question!

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\jay_s\anaconda3\lib\site-packages (0.0.post1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
#set independent variable to be the urbanization index, and the dependent variable (the one we want to predict) as the partisan lean
x = df_urban.urbanindex.values.reshape(435,1)
y = df_urban.pvi_22.values.reshape(435,1)

# %%
#set aside ~20% of the data as the test set
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 0)

# %%
#fit model using training data
regr = LinearRegression()  
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#print y-intercept and slope
print(regr.intercept_)
print(regr.coef_)
# Out:
# [-194.50396723]
# [[17.43471642]]

# %%
y_pre = regr.predict(x_test)

# %%
#RMSE
print(np.sqrt(metrics.mean_squared_error(y_test, y_pre)))
# Out:
# 19.770632336572028

# %%
plt.scatter(x, y, color='black')
plt.plot(x_test, y_pre, color='blue', linewidth=3)
plt.show()

# %% [markdown]
# ### The regression line seems to fit very well but that was a bit underwhelming. What if we factored in the state as a categorical variable, since we saw outliers like TX, FL and others earlier?

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
#In order to transform the strings in the state column into numerical features, we'll use one hot encoding
t = ColumnTransformer(transformers = [('onehot', OneHotEncoder(), ['state'])], remainder = 'passthrough')

# %%
feature_cols = ['urbanindex', 'state']
x = t.fit_transform(df_urban[feature_cols])
y = df_urban.pvi_22.values.reshape(435,1)

# %%
#435 records, and 51 features (1 x urbanization index, 50 x states with [0,1] values)
x.shape
# Out:
# (435, 51)

# %%
#set aside ~20% of the data as the test set
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 0)
regr2 = LinearRegression()  
regr2.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#print y-intercept and slope
print(regr2.intercept_)
print(regr2.coef_)
# Out:
# [-194.74741833]
# [[ 24.9176307   -5.42942651  -3.27663224 -17.78085351   3.59814498
#     0.10798753   3.70858457  12.35056715 -18.31186569 -10.25686358
#    27.70811039  13.56919784 -28.66784117   4.84275894 -11.03159425
#    -4.11072568 -11.66744599 -19.26812157  19.06046024  12.19976048
#    33.68735587   0.27612278   9.12257016 -16.35139055  14.15134054
#    25.68394323   3.33500614  -6.91855009 -15.02960846  15.30041479
#    -7.45894189  30.27337972 -17.06561877  -7.786283    -8.84302642
#   -20.36379829   9.00757503  -7.30942233   9.82168336  -4.33370396
#     3.34242941 -14.44840281 -13.21021925 -25.7410518    1.49097796
#     0.           5.73078479  16.9801644   -5.60556319   0.
#    17.77017645]]

# %%
state_coef = dict(zip(df_urban['state'].unique(), regr2.coef_[0][1:]))
print(state_coef)
# Out:
# {'NY': -5.429426511439108, 'NJ': -3.2766322394443126, 'CA': -17.7808535067124, 'IL': 3.5981449834085537, 'PA': 0.10798752712160974, 'MA': 3.708584572791062, 'VA': 12.350567153413655, 'FL': -18.311865693250443, 'MD': -10.256863575827689, 'TX': 27.708110390348487, 'CO': 13.56919784051172, 'MN': -28.667841166883512, 'WA': 4.842758943992792, 'WI': -11.031594247895505, 'AZ': -4.110725684622404, 'MI': -11.667445986576764, 'NV': -19.268121569523256, 'OH': 19.06046023638577, 'GA': 12.199760475744158, 'MO': 33.68735587154381, 'HI': 0.2761227836933393, 'OR': 9.12257016222921, 'IN': -16.351390554803956, 'KY': 14.15134054084917, 'RI': 25.683943234744103, 'NE': 3.335006139593095, 'NC': -6.918550093333189, 'CT': -15.02960846030358, 'TN': 15.300414786693839, 'LA': -7.458941889669174, 'UT': 30.27337971718367, 'OK': -17.065618774157617, 'KS': -7.786282997085598, 'NM': -8.843026423990292, 'SC': -20.36379828783263, 'DE': 9.007575030760739, 'NH': -7.309422333093298, 'IA': 9.821683362158991, 'AL': -4.333703964948316, 'AR': 3.3424294115006834, 'ID': -14.448402806169923, 'ME': -13.210219254043084, 'MS': -25.741051803984657, 'WV': 1.4909779612605663, 'ND': 0.0, 'VT': 5.730784785789203, 'SD': 16.98016440431199, 'MT': -5.605563192118453, 'AK': 0.0, 'WY': 17.770176448219235}

# %% [markdown]
# ### Interesting! At least with our limited sample size (435 records), we see that the states have an impact on the prediction of the partisan lean, with the exception of Alaska and North Dakota that have coefficients of 0. Also fascinating that California which is known to be a very blue state has a negative coefficient, which means it has to offset the impact of the urbanization index.

# %%
y_pre2 = regr2.predict(x_test)  
print(np.sqrt(metrics.mean_squared_error(y_test, y_pre2)))
# Out:
# 19.631070226469177

# %% [markdown]
# ### That's a slight improvement over the RMSE of our model with just urbanization index as the sole feature. We'll take it!

# %% [markdown]
# ### As a fun exercise, let's run all 435 districts through our second model, and predict the elected House representative using just the state and the urbanization index, assuming the partisan lean decides the vote. Any positive prediction we'll count as a Democratic vote, and any negative prediction we'll count as a Republican vote. Then let's compare to the final distribution of House seats in the next Congress being seated in January 2023.

# %%
#x defined above and already onehotencoded
Dem = 0
Rep = 0
Tossup = 0
for district in x:
    vote = regr2.predict(district)
    if vote > 0:
        Dem += 1
    elif vote < 0:
        Rep += 1
    else:
        Tossup += 1
        
print ("Dem: " + str(Dem))
print ("Rep: " + str(Rep))
print ("Tossup: " + str(Tossup))
# Out:
# Dem: 219
# Rep: 216
# Tossup: 0

# %% [markdown]
# ### We know that Republicans actually won 222 seats in the election, while Democrats won 213. This makes our model off by 6 seats (enough to decide the majority) but it only had 2 features to base a prediction off of! I can certainly see how political polling can get so complex!

# %% [markdown]
# ## Recap and Learnings

# %% [markdown]
# ### What originally started as a simple analysis of urbanization data pivoted into a few tangents and eventually into a simple predictive model using linear regression. While the original hypothesis that urban areas lean blue and rural areas lean red was confirmed, it was fascinating to see the subtle differences by state, where the outliers manifested, and how different density districts could sway in their partisan leaning. Even with limited data, we were able to create a prediction of partisan lean based on population density, and were even able to improve it slightly by folding in the state as an additional feature.

# %% [markdown]
# ### Because Congressional districts are redrawn every 10 years, it's difficult to extend the data backwards by district but the relationship between population density and partisan lean over time would be interesting to explore given more time and resources.
